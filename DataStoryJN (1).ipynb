# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("divorce1.csv")
print(df)
# Out:
#      Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0       2     2     4     1     0     0     0     0     0      0  ...      2
# 1       4     4     4     4     4     0     0     4     4      4  ...      2
# 2       2     2     2     2     1     3     2     1     1      2  ...      3
# 3       3     2     3     2     3     3     3     3     3      3  ...      2
# 4       2     2     1     1     1     1     0     0     0      0  ...      2
# 5       0     0     1     0     0     2     0     0     0      1  ...      2
# 6       3     3     3     2     1     3     4     3     2      2  ...      3
# 7       2     1     2     2     2     1     0     3     3      2  ...      0
# 8       2     2     1     0     0     4     1     3     3      3  ...      1
# 9       1     1     1     1     1     2     0     2     2      2  ...      2
# 10      4     4     4     3     4     0     0     4     4      3  ...      4
# ...

# %% [markdown]
# This is the attribute guide (what the columns stand for):
# (1) When one of our apologies apologizes when our discussions go in a bad direction, the issue does not extend.
# (2) I know we can ignore our differences, even if things get hard sometimes.
# (3) When we need it, we can take our discussions with my wife from the beginning and correct it.
# (4) When I argue with my wife, it will eventually work for me to contact him.
# (5) The time I spent with my wife is special for us.
# (6) We don't have time at home as partners.
# 7.	We are like two strangers who share the same environment at home rather than family.
# 8.	I enjoy our holidays with my wife.
# 9.	I enjoy traveling with my wife.
# 10.	My wife and most of our goals are common.
# 11.	I think that one day in the future, when I look back, I see that my wife and I are in harmony with each other.
# 12.	My wife and I have similar values in terms of personal freedom.
# 13.	My husband and I have similar entertainment.
# 14.	Most of our goals for people (children, friends, etc.) are the same.
# 15.	Our dreams of living with my wife are similar and harmonious
# 16.	We're compatible with my wife about what love should be
# 17.	We share the same views with my wife about being happy in your life
# 18.	My wife and I have similar ideas about how marriage should be
# 19.	My wife and I have similar ideas about how roles should be in marriage
# 20.	My wife and I have similar values in trust
# 21.	I know exactly what my wife likes.
# 22.	I know how my wife wants to be taken care of when she's sick.
# 23.	I know my wife's favorite food.
# 24.	I can tell you what kind of stress my wife is facing in her life.
# 25.	I have knowledge of my wife's inner world.
# 26.	I know my wife's basic concerns.
# 27.	I know what my wife's current sources of stress are.
# 28.	I know my wife's hopes and wishes.
# 29.	I know my wife very well.
# 30.	I know my wife's friends and their social relationships.
# 31.	I feel aggressive when I argue with my wife.
# 32.	When discussing with my wife, I usually use expressions such as â€œyou alwaysâ€œ or â€œyou neverâ€.
# 33.	I can use negative statements about my wife's personality during our discussions.
# 34.	I can use offensive expressions during our discussions.
# 35.	I can insult our discussions.
# 36.	I can be humiliating when we argue.
# 37.	My argument with my wife is not calm.
# 38.	I hate my wife's way of bringing it up.
# 39.	Fights often occur suddenly.
# 40.	We're just starting a fight before I know what's going on.
# 41.	When I talk to my wife about something, my calm suddenly breaks.
# 42.	When I argue with my wife, it only snaps in and I don't say a word.
# 43.	I'm mostly thirsty to calm the environment a little bit.
# 44.	Sometimes I think it's good for me to leave home for a while.
# 45.	I'd rather stay silent than argue with my wife.
# 46.	Even if I'm right in the argument, I'm thirsty not to upset the other side.
# 47.	When I argue with my wife, I remain silent because I am afraid of not being able to control my anger.
# 48.	I feel right in our discussions.
# 49.	I have nothing to do with what I've been accused of.
# 50.	I'm not actually the one who's guilty about what I'm accused of.
# 51.	I'm not the one who's wrong about problems at home.
# 52.	I wouldn't hesitate to tell her about my wife's inadequacy.
# 53.	When I discuss it, I remind her of my wife's inadequate issues.
# 54.	I'm not afraid to tell her about my wife's incompetence.

# %% [markdown]
# One of the rows that we deleted was question number 32 because the questions itself was filled with errors and didn't make sense.

# %%
df.pop('Atr32')
# Out:
# 0      2
# 1      4
# 2      3
# 3      3
# 4      1
# 5      1
# 6      2
# 7      1
# 8      1
# 9      1
# 10     4
# 11     4
# 12     4
# 13     4
# 14     4
# 15     4
# 16     4
# 17     3
# 18     4
# 19     3
# 20     4
# 21     4
# 22     3
# 23     4
# 24     4
# 25     4
# 26     4
# 27     4
# 28     4
# 29     4
# 30     4
# 31     3
# 32     3
# 33     4
# 34     3
# 35     4
# 36     3
# 37     4
# 38     4
# 39     3
# 40     4
# 41     4
# 42     4
# 43     4
# 44     4
# 45     4
# 46     4
# 47     4
# 48     4
# 49     4
# 50     4
# 51     4
# 52     3
# 53     4
# 54     3
# 55     4
# 56     3
# 57     3
# 58     3
# 59     4
# 60     4
# 61     4
# 62     4
# 63     4
# 64     3
# 65     3
# 66     3
# 67     3
# 68     3
# 69     4
# 70     4
# 71     4
# 72     3
# 73     4
# 74     4
# 75     2
# 76     3
# 77     3
# 78     3
# 79     4
# 80     3
# 81     3
# 82     3
# 83     3
# 84     0
# 85     0
# 86     0
# 87     0
# 88     0
# 89     2
# ...

# %%
print(df)
# Out:
#      Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0       2     2     4     1     0     0     0     0     0      0  ...      2
# 1       4     4     4     4     4     0     0     4     4      4  ...      2
# 2       2     2     2     2     1     3     2     1     1      2  ...      3
# 3       3     2     3     2     3     3     3     3     3      3  ...      2
# 4       2     2     1     1     1     1     0     0     0      0  ...      2
# 5       0     0     1     0     0     2     0     0     0      1  ...      2
# 6       3     3     3     2     1     3     4     3     2      2  ...      3
# 7       2     1     2     2     2     1     0     3     3      2  ...      0
# 8       2     2     1     0     0     4     1     3     3      3  ...      1
# 9       1     1     1     1     1     2     0     2     2      2  ...      2
# 10      4     4     4     3     4     0     0     4     4      3  ...      4
# ...

# %% [markdown]
# We also wanted to plot 2 different questions in order to see whether they were normally distirbuted between the groups that were married (class= 0), or divorced (class=1).

# %%
df['Atr18'].plot()
# Out:
# <Axes: >

# %%
df['Atr20'].plot()
# Out:
# <Axes: >

# %%
df['Atr39'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Next we wanted to plot 2 different questions on a density plot in order to see if it was normally distributed and centered.

# %%
filtered_df = df[df['Class'] == 1]
filtered_df['Atr18'].plot(kind='density')
plt.xlabel('Atr18')
plt.title('Density Plot of atr18 when class = 1')
plt.show()

# %%
filtered_df = df[df['Class'] == 0]
filtered_df['Atr18'].plot(kind='density')
plt.xlabel('Atr18')
plt.title('Density Plot of atr18 when class = 0')
plt.show()

# %%
filtered_df = df[df['Class'] == 0]
filtered_df['Atr20'].plot(kind='density')
plt.xlabel('Atr20')
plt.title('Density Plot of atr20 when class = 0')
plt.show()

# %%
filtered_df = df[df['Class'] == 1]
filtered_df['Atr20'].plot(kind='density')
plt.xlabel('Atr20')
plt.title('Density Plot of atr20 when class = 1')
plt.show()

# %%
filtered_df = df[df['Class'] == 1]
filtered_df['Atr39'].plot(kind='density')
plt.xlabel('Atr39')
plt.title('Density Plot of atr39 when class = 1')
plt.show()

# %%
filtered_df = df[df['Class'] == 0]
filtered_df['Atr39'].plot(kind='density')
plt.xlabel('Atr39')
plt.title('Density Plot of atr39 when class = 0')
plt.show()

# %%
df['Atr39'].plot(kind= 'density')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# When we merged the data to consider if the answers were going to vary based on marital status, we found that the answers were mirrored which is exactly what we thought was going to happen. We expected it to center itself around the mean.

# %%
# ONLY RUN THIS ONCE, RUNNING IT MORE THAN ONCE WILL UPDATE THE SUM, IT'S STILL SOMETHING WE HAVE TO WORK OUT
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

df_class = df.drop(columns=['Class'])

# Calculate the sum of values for each row
row_sums = df_class.sum(axis=1)

# Add the sums as a new column named 'sum' to the DataFrame
df['sum'] = row_sums

print(df['sum'])
# Out:
# 0       58
# 1      135
# 2      110
# 3      130
# 4       53
# 5       50
# 6      132
# 7      111
# 8      104
# 9       68
# 10     199
# 11     199
# 12     191
# 13     191
# 14     190
# 15     189
# 16     189
# 17     189
# 18     188
# 19     189
# 20     186
# 21     186
# 22     185
# 23     183
# 24     183
# 25     183
# 26     182
# 27     182
# 28     181
# 29     181
# 30     181
# 31     181
# 32     181
# 33     180
# 34     181
# 35     178
# 36     178
# 37     175
# 38     175
# 39     176
# 40     174
# 41     173
# 42     173
# 43     173
# 44     173
# 45     173
# 46     173
# 47     173
# 48     173
# 49     173
# 50     173
# 51     172
# 52     171
# 53     170
# 54     170
# 55     168
# 56     168
# 57     168
# 58     168
# 59     165
# 60     165
# 61     165
# 62     165
# 63     165
# 64     165
# 65     163
# 66     163
# 67     163
# 68     162
# 69     160
# 70     160
# 71     156
# 72     155
# 73     153
# 74     151
# 75     149
# ...

# %%
# Base regression method, here we add of the 
def predict_class(row_sum):
    if row_sum <= 106:
        return 0
    else:
        return 1    

df['Predicted class'] = df['sum'].apply(predict_class)

pd.set_option('display.max_rows', None)

# Print the DataFrame
print(df[['sum', 'Class', 'Predicted class']])
# Out:
#      sum  Class  Predicted class
# 0     58      1                0
# 1    135      1                1
# 2    110      1                1
# 3    130      1                1
# 4     53      1                0
# 5     50      1                0
# 6    132      1                1
# 7    111      1                1
# 8    104      1                0
# 9     68      1                0
# 10   199      1                1
# 11   199      1                1
# 12   191      1                1
# 13   191      1                1
# 14   190      1                1
# 15   189      1                1
# 16   189      1                1
# 17   189      1                1
# 18   188      1                1
# 19   189      1                1
# 20   186      1                1
# 21   186      1                1
# 22   185      1                1
# 23   183      1                1
# 24   183      1                1
# 25   183      1                1
# 26   182      1                1
# ...

# %%
# This is just put in place so when you run all it resets the sum automatically so it doesn't resum automatically (bug fix)
df.pop('sum')
# Out:
# 0       58
# 1      135
# 2      110
# 3      130
# 4       53
# 5       50
# 6      132
# 7      111
# 8      104
# 9       68
# 10     199
# 11     199
# 12     191
# 13     191
# 14     190
# 15     189
# 16     189
# 17     189
# 18     188
# 19     189
# 20     186
# 21     186
# 22     185
# 23     183
# 24     183
# 25     183
# 26     182
# 27     182
# 28     181
# 29     181
# 30     181
# 31     181
# 32     181
# 33     180
# 34     181
# 35     178
# 36     178
# 37     175
# 38     175
# 39     176
# 40     174
# 41     173
# 42     173
# 43     173
# 44     173
# 45     173
# 46     173
# 47     173
# 48     173
# 49     173
# 50     173
# 51     172
# 52     171
# 53     170
# 54     170
# 55     168
# 56     168
# 57     168
# 58     168
# 59     165
# 60     165
# 61     165
# 62     165
# 63     165
# 64     165
# 65     163
# 66     163
# 67     163
# 68     162
# 69     160
# 70     160
# 71     156
# 72     155
# 73     153
# 74     151
# 75     149
# ...

# %%
# 18: My wife and I have similar ideas about how marriage should be
# 20: My wife and I have similar values in trust
# 39: Fights often occur suddenly.

selected_columns = ['Atr18', 'Atr20', 'Atr39', 'Class']

# Creating a new DataFrame with selected columns
new_df = df[selected_columns].copy()

# Printing the new DataFrame
print(new_df)
# Out:
#      Atr18  Atr20  Atr39  Class
# 0        0      1      3      1
# 1        4      2      2      1
# 2        3      2      3      1
# 3        3      4      4      1
# 4        1      1      2      1
# 5        1      1      0      1
# 6        3      2      2      1
# 7        3      1      4      1
# 8        3      3      2      1
# 9        2      0      2      1
# 10       4      4      4      1
# 11       4      4      4      1
# 12       4      4      4      1
# 13       4      4      4      1
# 14       4      4      4      1
# 15       4      4      4      1
# 16       4      4      4      1
# 17       4      4      4      1
# 18       3      3      4      1
# 19       4      4      4      1
# 20       3      3      4      1
# 21       3      3      4      1
# 22       4      4      4      1
# 23       3      3      4      1
# 24       2      2      4      1
# 25       3      3      4      1
# 26       3      3      4      1
# 27       3      3      4      1
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans


# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(new_df['Atr18'][df['Class'] == 0], new_df['Atr20'][df['Class'] == 0], new_df['Atr39'][df['Class'] == 0], c='b', marker='o', label='Married')
ax.scatter(new_df['Atr18'][df['Class'] == 1], new_df['Atr20'][df['Class'] == 1], new_df['Atr39'][df['Class'] == 1], c='r', marker='o', label='Divorced')


# Set labels and title
ax.set_xlabel('Answer for 18')
ax.set_ylabel('Answer for 20')
ax.set_zlabel('Answer for 39')
ax.set_title('Clustering Plot')


# Perform K-means clustering
kmeans = KMeans(n_clusters=2)
kmeans.fit(new_df)
centroids = kmeans.cluster_centers_

# Plot centroids
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='r', marker='X', s=200)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

# Splitting data into features (X) and target variable (y)
X = new_df[['Atr18', 'Atr20', 'Atr39']]
y = new_df['Class']

# Splitting data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for training data
ax.scatter(X_train['Atr18'], X_train['Atr20'], X_train['Atr39'], c=y_train, marker='o', label='Training Data')

# Scatter plot for test data
ax.scatter(X_test['Atr18'], X_test['Atr20'], X_test['Atr39'], c='g', marker='o', label='Test Data')

# Set labels and title
ax.set_xlabel('Answer for 18')
ax.set_ylabel('Answer for 20')
ax.set_zlabel('Answer for 39')
ax.set_title('Clustering Plot')

# Perform K-means clustering on training data
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_train)
centroids = kmeans.cluster_centers_

# Plot centroids
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='r', marker='X', s=200, label='Centroids')

# Show legend & plot
ax.legend()
plt.show()

# %%
from sklearn.metrics import pairwise_distances_argmin_min

# Predicting classes for test data based on closest centroid
closest_centroids, _ = pairwise_distances_argmin_min(X_test, centroids)
predicted_class = closest_centroids

# Adding predicted class to test set
X_test_with_pred = X_test.copy()
X_test_with_pred['predicted_class'] = predicted_class

# Calculating accuracy
accuracy = (X_test_with_pred['predicted_class'] == y_test).mean()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9647058823529412
